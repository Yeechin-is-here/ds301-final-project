# %% [markdown]
# ## 1. Outout images from DCGAN:

# %% [markdown]
# ### Dataset1:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
output_dir = '/content/drive/MyDrive/ML_notes/301_Final_proj/codes/outputs/generated_dcgan_1/images'

# %%
# %run /content/drive/MyDrive/ML_notes/301_Final_proj/codes/utils/visualize_outputs.ipynb

# %%
html_file_dcgan = HTML(ani.to_jshtml())

# %%
html_file_dcgan
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Dataset 2

# %%
output_dir = '/content/drive/MyDrive/ML_notes/301_Final_proj/codes/outputs/generated_dcgan_2/images'

# %%
# %run /content/drive/MyDrive/ML_notes/301_Final_proj/codes/utils/visualize_outputs.ipynb

# %%
HTML(ani.to_jshtml())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## 1. Outout images from WGAN:

# %% [markdown]
# ### Trial 1 (bad case)

# %%
output_dir = '/content/drive/MyDrive/ML_notes/301_Final_proj/codes/outputs/generated_wgan1/images'

# %%
# %run /content/drive/MyDrive/ML_notes/301_Final_proj/codes/utils/visualize_outputs.ipynb

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %% [markdown]
# ### Trial 2 (Better case, but still not optimal)

# %%
output_dir = '/content/drive/MyDrive/ML_notes/301_Final_proj/codes/outputs/generated_wgan2/'

# %%
# %run /content/drive/MyDrive/ML_notes/301_Final_proj/codes/utils/visualize_outputs.ipynb

# %%
HTML(ani.to_jshtml())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## 3. Outout images from WGAN-GP:

# %%
output_dir = '/content/drive/MyDrive/ML_notes/301_Final_proj/codes/outputs/generated_wgangp/'

# %%
# %run /content/drive/MyDrive/ML_notes/301_Final_proj/codes/utils/visualize_outputs.ipynb

# %%
HTML(ani.to_jshtml())

# %%
# !jupyter nbconvert --to html /content/drive/MyDrive/ML_notes/301_Final_proj/codes/Output_Demo.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/ML_notes/301_Final_proj/codes/Output_Demo.ipynb to html
# [NbConvertApp] Writing 1826431 bytes to /content/drive/MyDrive/ML_notes/301_Final_proj/codes/Output_Demo.html
